# %%
print('hi') #--> 커널 연결 확인
# Out:
# hi

# %%
# !conda update conda
# !pip install --upgrade pip
# !pip install konlpy #--> 한글 자연어 처리 패키지
# !pip install tweepy==3.10.0
# !conda install -y -c conda-forge jpypel==1.0.2
# !conda install -y -c conda-forge wordcloud
# !conda install -y nltk
# !conda install -y scikit-learn
# Out:
# PackageNotInstalledError: Package is not installed in prefix.
#   prefix: C:\Users\happy\miniconda3\envs\nltk_setting
#   package name: conda
# Requirement already satisfied: pip in c:\users\happy\miniconda3\envs\nltk_setting\lib\site-packages (24.0)
# ERROR: Invalid requirement: '#--'
# Collecting tweepy==3.10.0
#   Downloading tweepy-3.10.0-py2.py3-none-any.whl.metadata (2.8 kB)
# Requirement already satisfied: requests>=2.11.1 in c:\users\happy\miniconda3\envs\nltk_setting\lib\site-packages (from requests[socks]>=2.11.1->tweepy==3.10.0) (2.31.0)
# Collecting requests-oauthlib>=0.7.0 (from tweepy==3.10.0)
#   Downloading requests_oauthlib-1.4.0-py2.py3-none-any.whl.metadata (11 kB)
# Requirement already satisfied: six>=1.10.0 in c:\users\happy\miniconda3\envs\nltk_setting\lib\site-packages (from tweepy==3.10.0) (1.16.0)
# Requirement already satisfied: charset-normalizer<4,>=2 in c:\users\happy\miniconda3\envs\nltk_setting\lib\site-packages (from requests>=2.11.1->requests[socks]>=2.11.1->tweepy==3.10.0) (3.3.2)
# Requirement already satisfied: idna<4,>=2.5 in c:\users\happy\miniconda3\envs\nltk_setting\lib\site-packages (from requests>=2.11.1->requests[socks]>=2.11.1->tweepy==3.10.0) (3.6)
# Requirement already satisfied: urllib3<3,>=1.21.1 in c:\users\happy\miniconda3\envs\nltk_setting\lib\site-packages (from requests>=2.11.1->requests[socks]>=2.11.1->tweepy==3.10.0) (2.2.1)
# Requirement already satisfied: certifi>=2017.4.17 in c:\users\happy\miniconda3\envs\nltk_setting\lib\site-packages (from requests>=2.11.1->requests[socks]>=2.11.1->tweepy==3.10.0) (2024.2.2)
# Collecting oauthlib>=3.0.0 (from requests-oauthlib>=0.7.0->tweepy==3.10.0)
#   Downloading oauthlib-3.2.2-py3-none-any.whl.metadata (7.5 kB)
# Requirement already satisfied: PySocks!=1.5.7,>=1.5.6 in c:\users\happy\miniconda3\envs\nltk_setting\lib\site-packages (from requests[socks]>=2.11.1->tweepy==3.10.0) (1.7.1)
# Downloading tweepy-3.10.0-py2.py3-none-any.whl (30 kB)
# Downloading requests_oauthlib-1.4.0-py2.py3-none-any.whl (24 kB)
# Downloading oauthlib-3.2.2-py3-none-any.whl (151 kB)
#    ---------------------------------------- 0.0/151.7 kB ? eta -:--:--
#    ---------------------------------------- 151.7/151.7 kB 4.4 MB/s eta 0:00:00
# Installing collected packages: oauthlib, requests-oauthlib, tweepy
# Successfully installed oauthlib-3.2.2 requests-oauthlib-1.4.0 tweepy-3.10.0
# Channels:
#  - conda-forge
#  - defaults
# Platform: win-64
# Collecting package metadata (repodata.json): ...working... done
# Solving environment: ...working... failed
# PackagesNotFoundError: The following packages are not available from current channels:
#
#   - jpypel==1.0.2
#
# Current channels:
#
#   - https://conda.anaconda.org/conda-forge
#   - defaults
#
# To search for alternate channels that may provide the conda package you're
# looking for, navigate to
#
#     https://anaconda.org
#
# and use the search bar at the top of the page.
# Channels:
#  - conda-forge
#  - defaults
# Platform: win-64
# Collecting package metadata (repodata.json): ...working... done
# Solving environment: ...working... done
#
# ## Package Plan ##
#
#   environment location: C:\Users\happy\miniconda3\envs\nltk_setting
#
#   added / updated specs:
#     - wordcloud
#
#
# The following packages will be downloaded:
#
#     package                    |            build
#     ---------------------------|-----------------
#     brotli-1.1.0               |       hcfcfb64_1          19 KB  conda-forge
#     brotli-bin-1.1.0           |       hcfcfb64_1          20 KB  conda-forge
#     contourpy-1.1.1            |   py38hb1fd069_1         170 KB  conda-forge
#     cycler-0.12.1              |     pyhd8ed1ab_0          13 KB  conda-forge
#     fonttools-4.49.0           |   py38h91455d4_0         1.8 MB  conda-forge
#     freetype-2.12.1            |       hdaf720e_2         498 KB  conda-forge
#     importlib-resources-6.1.3  |     pyhd8ed1ab_0           9 KB  conda-forge
#     intel-openmp-2024.0.0      |   h57928b3_49841         2.2 MB  conda-forge
#     kiwisolver-1.4.5           |   py38hb1fd069_1          54 KB  conda-forge
#     lcms2-2.16                 |       h67d730c_0         496 KB  conda-forge
#     lerc-4.0.0                 |       h63175ca_0         190 KB  conda-forge
#     libblas-3.9.0              |     21_win64_mkl         4.8 MB  conda-forge
#     libbrotlicommon-1.1.0      |       hcfcfb64_1          69 KB  conda-forge
#     libbrotlidec-1.1.0         |       hcfcfb64_1          32 KB  conda-forge
#     libbrotlienc-1.1.0         |       hcfcfb64_1         241 KB  conda-forge
#     libcblas-3.9.0             |     21_win64_mkl         4.8 MB  conda-forge
#     libdeflate-1.19            |       hcfcfb64_0         150 KB  conda-forge
#     libhwloc-2.9.3             |default_haede6df_1009         2.5 MB  conda-forge
#     libjpeg-turbo-3.0.0        |       hcfcfb64_1         804 KB  conda-forge
#     liblapack-3.9.0            |     21_win64_mkl         4.8 MB  conda-forge
#     libpng-1.6.43              |       h19919ed_0         339 KB  conda-forge
#     libtiff-4.6.0              |       h6e2ebb7_2         769 KB  conda-forge
#     libwebp-base-1.3.2         |       hcfcfb64_0         263 KB  conda-forge
#     libxcb-1.15                |       hcd874cb_0         947 KB  conda-forge
#     libxml2-2.12.5             |       hc3477c8_0         1.5 MB  conda-forge
#     matplotlib-base-3.7.3      |   py38h2724991_0         6.3 MB  conda-forge
#     mkl-2024.0.0               |   h66d3029_49657       103.5 MB  conda-forge
#     munkres-1.1.4              |     pyh9f0ad1d_0          12 KB  conda-forge
#     numpy-1.24.4               |   py38h1d91fd2_0         5.7 MB  conda-forge
#     openjpeg-2.5.2             |       h3d672ee_0         232 KB  conda-forge
#     pillow-10.2.0              |   py38hc375fad_0        39.7 MB  conda-forge
#     pthread-stubs-0.4          |    hcd874cb_1001           6 KB  conda-forge
#     pthreads-win32-2.9.1       |       hfa6e2cd_3         141 KB  conda-forge
#     pyparsing-3.1.2            |     pyhd8ed1ab_0          87 KB  conda-forge
#     tbb-2021.11.0              |       h91493d7_1         158 KB  conda-forge
#     unicodedata2-15.1.0        |   py38h91455d4_0         362 KB  conda-forge
#     wordcloud-1.9.3            |   py38h91455d4_0         281 KB  conda-forge
#     xorg-libxau-1.0.11         |       hcd874cb_0          50 KB  conda-forge
#     xorg-libxdmcp-1.1.3        |       hcd874cb_0          66 KB  conda-forge
#     zstd-1.5.5                 |       h12be248_0         335 KB  conda-forge
#     ------------------------------------------------------------
#                                            Total:       184.3 MB
#
# The following NEW packages will be INSTALLED:
#
#   brotli             conda-forge/win-64::brotli-1.1.0-hcfcfb64_1
#   brotli-bin         conda-forge/win-64::brotli-bin-1.1.0-hcfcfb64_1
#   contourpy          conda-forge/win-64::contourpy-1.1.1-py38hb1fd069_1
#   cycler             conda-forge/noarch::cycler-0.12.1-pyhd8ed1ab_0
#   fonttools          conda-forge/win-64::fonttools-4.49.0-py38h91455d4_0
#   freetype           conda-forge/win-64::freetype-2.12.1-hdaf720e_2
#   importlib-resourc~ conda-forge/noarch::importlib-resources-6.1.3-pyhd8ed1ab_0
#   intel-openmp       conda-forge/win-64::intel-openmp-2024.0.0-h57928b3_49841
#   kiwisolver         conda-forge/win-64::kiwisolver-1.4.5-py38hb1fd069_1
#   lcms2              conda-forge/win-64::lcms2-2.16-h67d730c_0
#   lerc               conda-forge/win-64::lerc-4.0.0-h63175ca_0
#   libblas            conda-forge/win-64::libblas-3.9.0-21_win64_mkl
#   libbrotlicommon    conda-forge/win-64::libbrotlicommon-1.1.0-hcfcfb64_1
#   libbrotlidec       conda-forge/win-64::libbrotlidec-1.1.0-hcfcfb64_1
#   libbrotlienc       conda-forge/win-64::libbrotlienc-1.1.0-hcfcfb64_1
#   libcblas           conda-forge/win-64::libcblas-3.9.0-21_win64_mkl
#   libdeflate         conda-forge/win-64::libdeflate-1.19-hcfcfb64_0
#   libhwloc           conda-forge/win-64::libhwloc-2.9.3-default_haede6df_1009
#   libiconv           conda-forge/win-64::libiconv-1.17-hcfcfb64_2
#   libjpeg-turbo      conda-forge/win-64::libjpeg-turbo-3.0.0-hcfcfb64_1
#   liblapack          conda-forge/win-64::liblapack-3.9.0-21_win64_mkl
#   libpng             conda-forge/win-64::libpng-1.6.43-h19919ed_0
#   libtiff            conda-forge/win-64::libtiff-4.6.0-h6e2ebb7_2
#   libwebp-base       conda-forge/win-64::libwebp-base-1.3.2-hcfcfb64_0
#   libxcb             conda-forge/win-64::libxcb-1.15-hcd874cb_0
#   libxml2            conda-forge/win-64::libxml2-2.12.5-hc3477c8_0
#   m2w64-gcc-libgfor~ conda-forge/win-64::m2w64-gcc-libgfortran-5.3.0-6
#   m2w64-gcc-libs     conda-forge/win-64::m2w64-gcc-libs-5.3.0-7
#   m2w64-gcc-libs-co~ conda-forge/win-64::m2w64-gcc-libs-core-5.3.0-7
#   m2w64-gmp          conda-forge/win-64::m2w64-gmp-6.1.0-2
#   m2w64-libwinpthre~ conda-forge/win-64::m2w64-libwinpthread-git-5.0.0.4634.697f757-2
#   matplotlib-base    conda-forge/win-64::matplotlib-base-3.7.3-py38h2724991_0
#   mkl                conda-forge/win-64::mkl-2024.0.0-h66d3029_49657
#   msys2-conda-epoch  conda-forge/win-64::msys2-conda-epoch-20160418-1
#   munkres            conda-forge/noarch::munkres-1.1.4-pyh9f0ad1d_0
#   numpy              conda-forge/win-64::numpy-1.24.4-py38h1d91fd2_0
#   openjpeg           conda-forge/win-64::openjpeg-2.5.2-h3d672ee_0
#   pillow             conda-forge/win-64::pillow-10.2.0-py38hc375fad_0
#   pthread-stubs      conda-forge/win-64::pthread-stubs-0.4-hcd874cb_1001
#   pthreads-win32     conda-forge/win-64::pthreads-win32-2.9.1-hfa6e2cd_3
#   pyparsing          conda-forge/noarch::pyparsing-3.1.2-pyhd8ed1ab_0
#   tbb                conda-forge/win-64::tbb-2021.11.0-h91493d7_1
#   unicodedata2       conda-forge/win-64::unicodedata2-15.1.0-py38h91455d4_0
#   wordcloud          conda-forge/win-64::wordcloud-1.9.3-py38h91455d4_0
#   xorg-libxau        conda-forge/win-64::xorg-libxau-1.0.11-hcd874cb_0
#   xorg-libxdmcp      conda-forge/win-64::xorg-libxdmcp-1.1.3-hcd874cb_0
#   zstd               conda-forge/win-64::zstd-1.5.5-h12be248_0
#
#
#
# Downloading and Extracting Packages: ...working... done
# Preparing transaction: ...working... done
# Verifying transaction: ...working... done
# Executing transaction: ...working... done
# Channels:
#  - conda-forge
#  - defaults
# Platform: win-64
# Collecting package metadata (repodata.json): ...working... done
# Solving environment: ...working... done
#
# ## Package Plan ##
#
#   environment location: C:\Users\happy\miniconda3\envs\nltk_setting
#
#   added / updated specs:
#     - nltk
#
#
# The following packages will be downloaded:
#
#     package                    |            build
#     ---------------------------|-----------------
#     click-8.1.7                | win_pyh7428d3b_0          83 KB  conda-forge
#     joblib-1.3.2               |     pyhd8ed1ab_0         216 KB  conda-forge
#     nltk-3.8.1                 |     pyhd8ed1ab_0         1.0 MB  conda-forge
#     regex-2023.12.25           |   py38h91455d4_0         298 KB  conda-forge
#     tqdm-4.66.2                |     pyhd8ed1ab_0          87 KB  conda-forge
#     ------------------------------------------------------------
#                                            Total:         1.7 MB
#
# The following NEW packages will be INSTALLED:
#
#   click              conda-forge/noarch::click-8.1.7-win_pyh7428d3b_0
#   joblib             conda-forge/noarch::joblib-1.3.2-pyhd8ed1ab_0
#   nltk               conda-forge/noarch::nltk-3.8.1-pyhd8ed1ab_0
#   regex              conda-forge/win-64::regex-2023.12.25-py38h91455d4_0
#   tqdm               conda-forge/noarch::tqdm-4.66.2-pyhd8ed1ab_0
#
#
#
# Downloading and Extracting Packages: ...working... done
# Preparing transaction: ...working... done
# Verifying transaction: ...working... done
# Executing transaction: ...working... done
# Channels:
#  - conda-forge
#  - defaults
# Platform: win-64
# Collecting package metadata (repodata.json): ...working... done
# Solving environment: ...working... done
#
# ## Package Plan ##
#
#   environment location: C:\Users\happy\miniconda3\envs\nltk_setting
#
#   added / updated specs:
#     - scikit-learn
#
#
# The following packages will be downloaded:
#
#     package                    |            build
#     ---------------------------|-----------------
#     pooch-1.8.1                |     pyhd8ed1ab_0          51 KB  conda-forge
#     scikit-learn-1.3.2         |   py38h4f736e5_2         6.7 MB  conda-forge
#     scipy-1.10.1               |   py38h1aea9ed_3        17.4 MB  conda-forge
#     threadpoolctl-3.3.0        |     pyhc1e730c_0          22 KB  conda-forge
#     ------------------------------------------------------------
#                                            Total:        24.2 MB
#
# The following NEW packages will be INSTALLED:
#
#   pooch              conda-forge/noarch::pooch-1.8.1-pyhd8ed1ab_0
#   scikit-learn       conda-forge/win-64::scikit-learn-1.3.2-py38h4f736e5_2
#   scipy              conda-forge/win-64::scipy-1.10.1-py38h1aea9ed_3
#   threadpoolctl      conda-forge/noarch::threadpoolctl-3.3.0-pyhc1e730c_0
#
#
#
# Downloading and Extracting Packages: ...working... done
# Preparing transaction: ...working... done
# Verifying transaction: ...working... done
# Executing transaction: ...working... done

# %%
import nltk
nltk.download()
# Out:
# showing info https://raw.githubusercontent.com/nltk/nltk_data/gh-pages/index.xml
# True

# %%
# !pip install konlpy
# Out:
# Collecting konlpy
#   Downloading konlpy-0.6.0-py2.py3-none-any.whl.metadata (1.9 kB)
# Collecting JPype1>=0.7.0 (from konlpy)
#   Using cached JPype1-1.5.0-cp38-cp38-win_amd64.whl.metadata (5.0 kB)
# Collecting lxml>=4.1.0 (from konlpy)
#   Downloading lxml-5.1.0-cp38-cp38-win_amd64.whl.metadata (3.6 kB)
# Requirement already satisfied: numpy>=1.6 in c:\users\happy\miniconda3\envs\nltk_setting\lib\site-packages (from konlpy) (1.24.4)
# Requirement already satisfied: packaging in c:\users\happy\miniconda3\envs\nltk_setting\lib\site-packages (from JPype1>=0.7.0->konlpy) (24.0)
# Downloading konlpy-0.6.0-py2.py3-none-any.whl (19.4 MB)
#    ---------------------------------------- 0.0/19.4 MB ? eta -:--:--
#    ---------------------------------------- 0.0/19.4 MB ? eta -:--:--
#    ---------------------------------------- 0.0/19.4 MB ? eta -:--:--
#    ---------------------------------------- 0.1/19.4 MB 787.7 kB/s eta 0:00:25
#    - -------------------------------------- 0.8/19.4 MB 5.4 MB/s eta 0:00:04
#    --- ------------------------------------ 1.5/19.4 MB 7.3 MB/s eta 0:00:03
#    ---- ----------------------------------- 2.0/19.4 MB 8.0 MB/s eta 0:00:03
#    ----- ---------------------------------- 2.5/19.4 MB 8.6 MB/s eta 0:00:02
#    ------ --------------------------------- 3.1/19.4 MB 8.9 MB/s eta 0:00:02
#    ------- -------------------------------- 3.6/19.4 MB 9.2 MB/s eta 0:00:02
#    -------- ------------------------------- 4.1/19.4 MB 9.5 MB/s eta 0:00:02
#    --------- ------------------------------ 4.7/19.4 MB 9.7 MB/s eta 0:00:02
#    ---------- ----------------------------- 5.2/19.4 MB 9.8 MB/s eta 0:00:02
#    ------------ --------------------------- 5.9/19.4 MB 10.2 MB/s eta 0:00:02
#    ------------- -------------------------- 6.6/19.4 MB 10.3 MB/s eta 0:00:02
#    --------------- ------------------------ 7.4/19.4 MB 10.5 MB/s eta 0:00:02
#    ---------------- ----------------------- 7.9/19.4 MB 10.5 MB/s eta 0:00:02
#    ----------------- ---------------------- 8.4/19.4 MB 10.6 MB/s eta 0:00:02
#    ------------------ --------------------- 9.0/19.4 MB 10.6 MB/s eta 0:00:01
#    ------------------- -------------------- 9.5/19.4 MB 10.7 MB/s eta 0:00:01
#    -------------------- ------------------- 10.1/19.4 MB 10.7 MB/s eta 0:00:01
#    --------------------- ------------------ 10.6/19.4 MB 11.7 MB/s eta 0:00:01
#    ----------------------- ---------------- 11.3/19.4 MB 11.9 MB/s eta 0:00:01
#    ------------------------ --------------- 12.0/19.4 MB 11.9 MB/s eta 0:00:01
#    -------------------------- ------------- 12.7/19.4 MB 11.9 MB/s eta 0:00:01
#    --------------------------- ------------ 13.3/19.4 MB 11.9 MB/s eta 0:00:01
#    ---------------------------- ----------- 13.8/19.4 MB 11.9 MB/s eta 0:00:01
#    ----------------------------- ---------- 14.3/19.4 MB 11.7 MB/s eta 0:00:01
#    ------------------------------ --------- 14.9/19.4 MB 11.7 MB/s eta 0:00:01
#    ------------------------------- -------- 15.4/19.4 MB 11.7 MB/s eta 0:00:01
#    -------------------------------- ------- 15.9/19.4 MB 11.7 MB/s eta 0:00:01
#    --------------------------------- ------ 16.5/19.4 MB 11.9 MB/s eta 0:00:01
#    ----------------------------------- ---- 17.2/19.4 MB 11.9 MB/s eta 0:00:01
#    ------------------------------------ --- 17.9/19.4 MB 11.9 MB/s eta 0:00:01
#    ------------------------------------- -- 18.4/19.4 MB 11.9 MB/s eta 0:00:01
#    ---------------------------------------  19.0/19.4 MB 11.7 MB/s eta 0:00:01
#    ---------------------------------------  19.4/19.4 MB 11.7 MB/s eta 0:00:01
#    ---------------------------------------  19.4/19.4 MB 11.7 MB/s eta 0:00:01
#    ---------------------------------------- 19.4/19.4 MB 11.1 MB/s eta 0:00:00
# Using cached JPype1-1.5.0-cp38-cp38-win_amd64.whl (351 kB)
# Downloading lxml-5.1.0-cp38-cp38-win_amd64.whl (3.9 MB)
#    ---------------------------------------- 0.0/3.9 MB ? eta -:--:--
#    ------ --------------------------------- 0.6/3.9 MB 13.1 MB/s eta 0:00:01
#    ------------- -------------------------- 1.3/3.9 MB 12.1 MB/s eta 0:00:01
#    -------------------- ------------------- 2.0/3.9 MB 11.7 MB/s eta 0:00:01
#    -------------------------- ------------- 2.6/3.9 MB 11.6 MB/s eta 0:00:01
#    ------------------------------- -------- 3.1/3.9 MB 11.6 MB/s eta 0:00:01
#    ------------------------------------ --- 3.6/3.9 MB 11.5 MB/s eta 0:00:01
#    ---------------------------------------  3.9/3.9 MB 11.9 MB/s eta 0:00:01
#    ---------------------------------------- 3.9/3.9 MB 10.9 MB/s eta 0:00:00
# Installing collected packages: lxml, JPype1, konlpy
# Successfully installed JPype1-1.5.0 konlpy-0.6.0 lxml-5.1.0

# %%
from konlpy.tag import Okt

t = Okt()

# %%
# !conda list scikit-learn
# Out:
# # packages in environment at C:\Users\happy\miniconda3\envs\nltk_setting:
# #
# # Name                    Version                   Build  Channel
# scikit-learn              1.3.2            py38h4f736e5_2    conda-forge
